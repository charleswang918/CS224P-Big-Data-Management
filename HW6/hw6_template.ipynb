# %%
from pyflink.datastream.connectors.file_system import FileSource, StreamFormat
from pyflink.datastream import StreamExecutionEnvironment
from pyflink.datastream.functions import MapFunction
from pyflink.common.watermark_strategy import WatermarkStrategy
from pyflink.datastream import RuntimeExecutionMode
from pyflink.table import TableEnvironment, EnvironmentSettings
from pyflink.datastream.functions import ReduceFunction
from pyflink.datastream.functions import KeyedProcessFunction
from pyflink.datastream.state import ValueStateDescriptor
from pyflink.common.typeinfo import Types
from pyflink.datastream.functions import RuntimeContext
from datetime import datetime
import json

class JsonObjectMapFunction(MapFunction):
    def map(self, value):
        return json.loads(value)

def read_json_as_datastream(file_path: str, env: StreamExecutionEnvironment):
    source = FileSource.for_record_stream_format(StreamFormat.text_line_format(), file_path).build()
    data_stream = env.from_source(source, WatermarkStrategy.no_watermarks(), "txt_source")    
    parsed_stream = data_stream.map(JsonObjectMapFunction())
    return parsed_stream

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/chuqiwang/Documents/UCI/CS224P/assignments/HW6'

# %%
# Path of the data files, change it accordingly
records_path = "zot-music-dataset-hw6/Records.jsonl"
review_likes_path = "zot-music-dataset-hw6/ReviewLikes.jsonl"
reviews_path = "zot-music-dataset-hw6/Reviews.jsonl"
sessions_path = "zot-music-dataset-hw6/Sessions.jsonl"
users_path = "zot-music-dataset-hw6/Users.jsonl"

# %%
# Q1.a
# Your Answer: 
env = StreamExecutionEnvironment.get_execution_environment()
env.set_runtime_mode(RuntimeExecutionMode.BATCH)
# Your code here
user_stream = read_json_as_datastream(users_path, env)
class PrintTypeMapFunction(MapFunction):
    def map(self, value):
        print(f"Data: {value}, Type: {type(value)}")
        return value
user_stream = user_stream.map(PrintTypeMapFunction())
env.execute("Q1.a")
# Out:
# Data: {'user_id': 'user_vjWSqut3SK-2', 'email': 'anna49@college.edu', 'joined_date': '2015-01-26', 'nickname': 'anna49', 'address': {'street': '247 Acevedo Overpass Suite 623', 'state': 'Michigan', 'zip': '31431'}, 'genres': ['Jazz', 'Disco', 'Hip-Hop', 'Folk'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Michael', 'last_name': 'Ramirez'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_ECQlpCSMQfKm', 'email': 'zwarren@foxmail.com', 'joined_date': '2015-12-26', 'nickname': 'zwarren', 'address': {'street': '649 Michael Fork Apt. 573', 'city': 'Ashleyshire', 'zip': '62250'}, 'genres': ['Classical', 'Funk', 'Country', 'Disco'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Thomas', 'last_name': 'Holmes'}, 'stage_name': 'panderson', 'bio': 'Quality morning fire rule open. Keep continue attack want school certainly. Special check many listen travel.\nSort continue thank cover window turn major. Significant task image.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_KZfYEcAaRDaG', 'email': 'justinlam@hotmail.com', 'joined_date': '2016-06-18', 'nickname': 'justinlam', 'address': {'street': '5030 Stephanie Valley', 'state': 'Montana', 'zip': '37563'}, 'genres': ['Soul', 'Jazz', 'Country', 'Blues'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Ryan', 'last_name': 'Anderson'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_oU2SZCzYQvGw', 'email': 'browncarrie@icloud.com', 'joined_date': '2017-08-03', 'nickname': 'browncarrie', 'address': {'state': 'Rhode Island', 'zip': '23550'}, 'genres': ['Jazz', 'Hip-Hop', 'Indie', 'Classical'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Hannah', 'last_name': 'Martin'}, 'stage_name': 'ghernandez', 'bio': 'Hour find compare official choice necessary. About several father under professor message hit.\nHer every against subject. President garden movement make place pick environmental.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_U7Kei2xQQGmQ', 'email': 'zramsey@hotmail.com', 'joined_date': '2019-11-15', 'nickname': 'zramsey', 'address': {'street': '501 Ashley Loaf', 'city': 'Alexanderchester', 'state': 'Arkansas'}, 'genres': ['Country', 'Soul', 'Indie', 'Folk', 'Metal'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Michael', 'last_name': 'Scott'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_h0R3q0zaRbKV', 'email': 'jonesgregory@college.edu', 'joined_date': '2016-05-30', 'nickname': 'jonesgregory', 'address': {'city': 'Jacquelineport', 'state': 'New Jersey', 'zip': '62387'}, 'genres': ['Metal', 'Indie', 'Soul', 'Blues', 'Classical', 'Electronic'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Heather', 'last_name': 'Jones'}, 'bio': 'Nice model this. Foreign room value two.\nHouse by good arm behind rich. Each sort difficult deal.\nWell fish executive. Whom address team right. During well crime answer.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_IvP64nTPQ12P', 'email': 'brianmatthews@protonmail.com', 'joined_date': '2016-09-29', 'nickname': 'brianmatthews', 'address': {'street': '45206 Rios Field Suite 965', 'state': 'Florida', 'zip': '35003'}, 'genres': ['Latin', 'Blues', 'Hip-Hop', 'Indie'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Emily', 'last_name': 'Peterson'}, 'stage_name': 'gallegosjeremy', 'bio': 'Lead over agree sort old ground. Purpose whose know get own court tend employee. Someone including woman card. Parent Congress back night.\nFill Mrs increase past.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_cs1e2h27QqWL', 'email': 'joel00@gmail.com', 'joined_date': '2021-03-17', 'nickname': 'joel00', 'address': {'street': '4880 Cassandra Street Apt. 158', 'city': 'Lake Patrickstad', 'state': 'Kentucky', 'zip': '66019'}, 'genres': ['Soul', 'Latin', 'Hip-Hop', 'R&B', 'Punk', 'Jazz', 'Rock', 'Classical'], 'is_listener': False, 'is_artist': True, 'stage_name': 'sharon89', 'bio': 'Structure artist growth prevent money clear Republican. Wind which back property audience simple. Next late marriage cell movement action today.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_gpQZcJRmQbyt', 'email': 'ibrown@outlook.com', 'joined_date': '2021-04-21', 'nickname': 'ibrown', 'address': {'street': '8894 Jenna Valleys', 'city': 'Barkertown', 'state': 'Louisiana', 'zip': '38790'}, 'genres': ['Techno', 'Disco', 'Folk', 'Metal', 'Latin', 'Jazz'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Vanessa', 'last_name': 'Ibarra'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_9sltGaXKS96g', 'email': 'reevesgeorge@university.edu', 'joined_date': '2018-10-23', 'nickname': 'reevesgeorge', 'address': {'street': '24783 Tucker Coves Suite 484', 'city': 'Jaimemouth', 'state': 'Rhode Island', 'zip': '15288'}, 'genres': ['Indie', 'Pop', 'Disco'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Stephanie', 'last_name': 'Berry'}, 'stage_name': 'graysamantha', 'bio': 'Else reveal role air about at beyond. Feel bed drug soon water deal.\nReturn Mrs research. He now society enjoy news that. My to beautiful color town standard stop.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_uvgCNu7qRpmg', 'email': 'barbaragardner@foxmail.com', 'joined_date': '2016-07-07', 'nickname': 'barbaragardner', 'address': {'city': 'Heidiport', 'state': 'Maryland', 'zip': '57700'}, 'genres': ['Country', 'Blues', 'Indie', 'Soul', 'Metal'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Sandra', 'last_name': 'Malone'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Evsij6G-Sge-', 'email': 'kristin31@university.edu', 'joined_date': '2016-08-22', 'nickname': 'kristin31', 'address': {'street': '98252 Michael Lock Suite 149', 'city': 'South Leslie', 'state': 'Kentucky', 'zip': '24174'}, 'genres': ['Techno', 'Electronic', 'Reggae', 'Pop', 'Punk', 'Latin', 'Folk'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Savannah', 'last_name': 'Pugh'}, 'stage_name': 'taylorthomas', 'bio': 'Boy record level realize. Score example modern offer education describe. Remain brother military.\nFree future attention action how begin group.'}, Type: <class 'dict'>
# Data: {'user_id': 'user__YjQv98vTM2E', 'email': 'candace45@protonmail.com', 'joined_date': '2020-04-28', 'nickname': 'candace45', 'address': {'street': '88540 Dawn Flats', 'city': 'North Amy', 'zip': '34586'}, 'genres': ['Latin', 'Soul', 'Folk', 'Disco', 'Country'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Dominic', 'last_name': 'Mills'}, 'stage_name': 'barnesveronica', 'bio': 'Nor investment past great activity everything charge. General so that start.\nEnough eight condition build. Reflect stop cover right road player know.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_c86t_XOYS72h', 'email': 'helen93@outlook.com', 'joined_date': '2022-05-27', 'nickname': 'helen93', 'address': {'street': '498 Roberts Greens Apt. 630', 'city': 'Kennethstad', 'state': 'Hawaii', 'zip': '80678'}, 'genres': ['Metal', 'Latin', 'Soul', 'Jazz', 'Classical', 'Hip-Hop'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'James', 'last_name': 'Bryant'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_aWUMTLoQTJem', 'email': 'nicole38@college.edu', 'joined_date': '2015-03-03', 'nickname': 'nicole38', 'address': {'street': '30627 Kirk Stream Apt. 711', 'city': 'Andrewside', 'zip': '19348'}, 'genres': ['Rock', 'Pop', 'Gospel', 'Classical'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'John', 'last_name': 'Wilson'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_wRl5wzeHQveG', 'email': 'randallclark@mail.com', 'joined_date': '2017-11-16', 'nickname': 'randallclark', 'address': {'street': '1474 Rogers Locks Apt. 458', 'state': 'Rhode Island', 'zip': '54725'}, 'genres': ['Funk', 'Gospel', 'Latin', 'Indie', 'Punk', 'Hip-Hop', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Danny', 'last_name': 'Mitchell'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_3euTkRP7QweQ', 'email': 'littlekatherine@college.edu', 'joined_date': '2019-08-10', 'nickname': 'littlekatherine', 'address': {'city': 'New Angelafurt', 'zip': '77039'}, 'genres': ['R&B', 'Country', 'Indie', 'Jazz'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Mark', 'last_name': 'Rivers'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_yYThC7ZaSmyG', 'email': 'chelsealawson@icloud.com', 'joined_date': '2015-06-19', 'nickname': 'chelsealawson', 'address': {'street': '183 Nancy Island Suite 090', 'city': 'Lake Deannaton', 'state': 'North Carolina', 'zip': '10206'}, 'genres': ['Pop', 'Hip-Hop', 'Jazz', 'R&B', 'Soul', 'Metal', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Jamie', 'last_name': 'Farley'}, 'bio': 'Source ball low month big visit various. Himself network improve.\nMoney him population factor turn around. Where risk small establish could hundred.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_ZDcTnYm6TyWP', 'email': 'laura71@college.edu', 'joined_date': '2021-01-03', 'nickname': 'laura71', 'address': {'street': '2609 Douglas Valleys', 'city': 'North Kendra', 'state': 'Tennessee', 'zip': '12896'}, 'genres': ['Soul', 'Indie', 'Blues'], 'is_listener': False, 'is_artist': True, 'stage_name': 'bergeric', 'bio': 'Outside dinner age weight start attorney talk risk. Certain despite trade arm not surface including.\nPicture model religious fight. So one firm worker the bag.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_3-FnSJJ7TXGx', 'email': 'deborah79@outlook.com', 'joined_date': '2015-02-19', 'nickname': 'deborah79', 'address': {'street': '8256 Glenda Highway Apt. 808', 'city': 'Lake Ruben'}, 'genres': ['Folk', 'Latin', 'Hip-Hop', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Nathan', 'last_name': 'Love'}, 'stage_name': 'noah29', 'bio': 'Perform difference building black official scene woman. Budget cause me month.\nMention him before always use let. Join information entire oil concern fact. Money treat single partner billion.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_568RFdWFQqiR', 'email': 'smithmichael@outlook.com', 'joined_date': '2021-03-27', 'nickname': 'smithmichael', 'address': {'street': '42334 Burke Row', 'state': 'New Mexico', 'zip': '30038'}, 'genres': ['Country', 'Rock', 'Indie', 'Jazz', 'Reggae'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Alexandria', 'last_name': 'Lewis'}, 'bio': 'Soon east suddenly step test. Traditional direction close analysis.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_PZZ3lJe_Roab', 'email': 'pinedakelli@yahoo.com', 'joined_date': '2017-09-04', 'nickname': 'pinedakelli', 'address': {'street': '4554 Pruitt Highway Suite 286', 'city': 'Sandrashire', 'zip': '72700'}, 'genres': ['Gospel', 'Soul', 'Reggae', 'Electronic', 'Funk', 'R&B'], 'is_listener': False, 'is_artist': True, 'stage_name': 'nkramer', 'bio': 'Cell cultural day decide finish agency. List sense there pass son top simply. Have man board discover likely study case.\nNote series it before evidence benefit.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_w6JFwfgwQzKw', 'email': 'icook@hotmail.com', 'joined_date': '2016-02-13', 'nickname': 'icook', 'address': {'street': '7061 Ortiz Trail Suite 663', 'city': 'South Sylviabury', 'state': 'Georgia', 'zip': '98489'}, 'genres': ['Folk', 'Indie', 'Rock', 'Techno'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Emily', 'last_name': 'Dixon'}, 'stage_name': 'handerson', 'bio': 'Feeling analysis professor opportunity. Either figure line weight. Reach check without give. Perhaps decade building even staff room.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_8vaymwbtTr-S', 'email': 'respinoza@icloud.com', 'joined_date': '2018-08-24', 'nickname': 'respinoza', 'address': {'street': '164 Ryan Via Apt. 109', 'state': 'Alaska', 'zip': '25989'}, 'genres': ['Blues', 'Latin', 'Soul', 'Punk'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Scott', 'last_name': 'Woods'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_hGRzLt_vQpWC', 'email': 'barrettricky@protonmail.com', 'joined_date': '2018-08-21', 'nickname': 'barrettricky', 'address': {'street': '053 Rebecca Islands', 'city': 'Lake Joe', 'state': 'Utah', 'zip': '14777'}, 'genres': ['R&B', 'Folk'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Robert', 'last_name': 'Smith'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_PbWIWIlASSC0', 'email': 'sherry98@outlook.com', 'joined_date': '2017-01-19', 'nickname': 'sherry98', 'address': {'street': '43731 Danielle Junctions', 'city': 'East Erin', 'zip': '44459'}, 'genres': ['Metal', 'Blues', 'Jazz', 'Latin', 'Folk', 'Techno', 'Gospel'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Daniel', 'last_name': 'Wilkins'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_g8BPW3eUSGiC', 'email': 'ndoyle@university.edu', 'joined_date': '2017-03-20', 'nickname': 'ndoyle', 'address': {'street': '296 Brown Dam', 'state': 'Oregon', 'zip': '89654'}, 'genres': ['Techno', 'Country', 'Jazz'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Michelle', 'last_name': 'Adams'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_ioBi4MgSQoiD', 'email': 'gclayton@protonmail.com', 'joined_date': '2018-04-16', 'nickname': 'gclayton', 'address': {'street': '79145 Reed Heights Suite 851', 'city': 'East Mario', 'zip': '77128'}, 'genres': ['Hip-Hop', 'Latin', 'Classical', 'Techno', 'Blues', 'Jazz', 'Soul', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Jeffrey', 'last_name': 'Franco'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_0O-KL6nZQkit', 'email': 'brucewesley@hotmail.com', 'joined_date': '2021-09-27', 'nickname': 'brucewesley', 'address': {}, 'genres': ['R&B', 'Classical', 'Funk', 'Techno'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Aaron', 'last_name': 'Carson'}, 'stage_name': 'martineztony', 'bio': 'Vote fine chance arrive. Music by eye son.\nAffect too successful. Degree audience shake agency.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_zFzYhOkJRjuf', 'email': 'gomezbrittany@foxmail.com', 'joined_date': '2022-05-24', 'nickname': 'gomezbrittany', 'address': {'street': '1234 Gerald Tunnel', 'city': 'North Stephen', 'state': 'Wyoming'}, 'genres': ['Hip-Hop', 'Rock', 'Folk', 'Classical', 'Punk', 'Electronic', 'Indie', 'Funk', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Holly', 'last_name': 'Woodward'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_uxjeYH87T56-', 'email': 'zmason@gmail.com', 'joined_date': '2019-08-06', 'nickname': 'zmason', 'address': {'street': '097 Maureen Summit', 'city': 'Millerfurt', 'state': 'Nebraska', 'zip': '36412'}, 'genres': ['Country', 'Reggae', 'R&B', 'Rock', 'Indie', 'Latin', 'Electronic', 'Gospel', 'Jazz', 'Soul'], 'is_listener': False, 'is_artist': True, 'stage_name': 'ann40', 'bio': 'Though sense also another. Bed take offer total remain.\nLocal plan his sign impact. Bad season next food when.\nOf final policy sing. Color individual notice item. Simply must up happen entire future.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_P1ara1joTVCc', 'email': 'gerald43@icloud.com', 'joined_date': '2018-08-06', 'nickname': 'gerald43', 'address': {'street': '33136 George Parkway', 'state': 'Illinois', 'zip': '86294'}, 'genres': ['Classical', 'Disco', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Karen', 'last_name': 'Molina'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Vt8dp4IISYeh', 'email': 'douglas76@icloud.com', 'joined_date': '2018-08-24', 'nickname': 'douglas76', 'address': {'city': 'North Kathrynmouth', 'state': 'Ohio', 'zip': '04861'}, 'genres': ['Folk', 'Techno', 'Soul', 'Gospel', 'Country', 'Blues', 'Disco', 'Metal'], 'is_listener': False, 'is_artist': True, 'stage_name': 'eric92', 'bio': 'Through firm believe move skin not. Save later article girl low.\nChoose three chance similar sound voice.\nArrive hotel thought knowledge likely. Next the religious administration animal tell what.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_P74qRgvASHGK', 'email': 'sandersjanet@yahoo.com', 'joined_date': '2019-12-30', 'nickname': 'sandersjanet', 'address': {'street': '290 Sanchez Lake', 'city': 'Jonesland', 'state': 'Washington', 'zip': '61933'}, 'genres': ['Country', 'Techno', 'R&B', 'Indie'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Lynn', 'last_name': 'Mullins'}, 'bio': 'Enjoy security doctor sure sing who administration fear. Wish truth blood where allow list future build.\nAccount daughter drop head well. Ready year machine should fine. Difficult parent public.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_Wxx-bvtARVK5', 'email': 'adamseric@yahoo.com', 'joined_date': '2016-03-04', 'nickname': 'adamseric', 'address': {'street': '427 Larson Highway', 'city': 'Walterhaven', 'zip': '69266'}, 'genres': ['Hip-Hop', 'Indie', 'R&B', 'Classical', 'Soul', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Anita', 'last_name': 'Howard'}, 'stage_name': 'andersonnorman', 'bio': 'Start serious still letter church this lot must. Century during body finally discover learn. Six two court agent toward physical chance.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_UqUYfsm3RHC0', 'email': 'william57@mail.com', 'joined_date': '2016-07-07', 'nickname': 'william57', 'address': {'street': '372 Crystal Ranch Apt. 263', 'city': 'Richardberg', 'state': 'Maine', 'zip': '91457'}, 'genres': ['Jazz', 'Punk', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Blake', 'last_name': 'Johnson'}, 'stage_name': 'ehester', 'bio': 'Expect family reveal part he three million six. Friend avoid old care improve beyond.\nSign fly argue peace.\nOffice form red Congress current. Low down exactly important.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_f0ewBib3T860', 'email': 'elara@college.edu', 'joined_date': '2017-12-13', 'nickname': 'elara', 'address': {'street': '4430 Elizabeth Mount Suite 943', 'city': 'Timothyside', 'zip': '91998'}, 'genres': ['Pop', 'Techno', 'Folk', 'Country', 'Punk', 'Hip-Hop'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Jennifer', 'last_name': 'Wyatt'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_eH84BFGSSQW_', 'email': 'danielbeck@mail.com', 'joined_date': '2017-02-23', 'nickname': 'danielbeck', 'address': {'street': '485 Powell Streets Apt. 136', 'city': 'Francohaven', 'state': 'North Carolina', 'zip': '35082'}, 'genres': ['Gospel', 'Electronic'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Nicole', 'last_name': 'Giles'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_PGNmYMnOSDqX', 'email': 'linda38@outlook.com', 'joined_date': '2021-09-16', 'nickname': 'linda38', 'address': {'city': 'Stephentown', 'state': 'Connecticut', 'zip': '12838'}, 'genres': ['R&B', 'Punk', 'Hip-Hop'], 'is_listener': False, 'is_artist': True, 'stage_name': 'jnichols', 'bio': 'College view moment religious peace less body. Drug itself note claim treatment. Everybody position bed available fire responsibility security performance. Agree benefit voice easy.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_y65kyOHVSNu1', 'email': 'reedbrian@yahoo.com', 'joined_date': '2020-12-07', 'nickname': 'reedbrian', 'address': {'city': 'West Anthonyburgh', 'state': 'Wyoming', 'zip': '44758'}, 'genres': ['Folk', 'Disco', 'Electronic', 'Techno', 'Metal'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Isabella', 'last_name': 'Anthony'}, 'stage_name': 'brownchristine', 'bio': 'Offer experience television go they laugh rate.\nPush wall trouble level pull include film.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_vbpoeTqITiaC', 'email': 'rjohnson@outlook.com', 'joined_date': '2017-05-28', 'nickname': 'rjohnson', 'address': {'street': '94093 Underwood Well Suite 288', 'city': 'Lake Tyler', 'zip': '10183'}, 'genres': ['Jazz', 'Pop', 'Classical', 'Metal', 'Electronic', 'Blues', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Melody', 'last_name': 'Brown'}, 'stage_name': 'fostermichael', 'bio': 'Moment south simple you writer it. Among nation major specific him sometimes phone. List their two.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_xGI_8X2VTT2O', 'email': 'garydavies@yahoo.com', 'joined_date': '2017-02-02', 'nickname': 'garydavies', 'address': {'street': '735 Monique Meadow Suite 553', 'city': 'Deanstad', 'state': 'Illinois'}, 'genres': ['Soul', 'Jazz', 'Electronic', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Lisa', 'last_name': 'Townsend'}, 'stage_name': 'qdurham', 'bio': 'Hundred mention natural laugh school hundred. Order charge scientist people station happy. At organization career reality watch.\nCover skill office under above event through.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_Kdk3-fUHRo-x', 'email': 'joseph37@yahoo.com', 'joined_date': '2019-11-17', 'nickname': 'joseph37', 'address': {'street': '06666 Kristin Plaza', 'city': 'Harrellberg', 'state': 'Georgia', 'zip': '28117'}, 'genres': ['Metal', 'Country'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Jonathan', 'last_name': 'Evans'}, 'stage_name': 'keith10', 'bio': 'Someone view check.\nEnvironment fear either plant. Run believe determine.\nHistory property arm among former away organization. Hour page cup truth.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_Av16YXvNQfiN', 'email': 'rshaffer@college.edu', 'joined_date': '2022-07-21', 'nickname': 'rshaffer', 'address': {'street': '29306 Diana Spurs Apt. 038', 'city': 'Kellyburgh', 'zip': '35131'}, 'genres': ['R&B', 'Blues', 'Classical', 'Reggae'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Amanda', 'last_name': 'Johnson'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_pxWGH4h0SMOq', 'email': 'wyoung@hotmail.com', 'joined_date': '2016-08-24', 'nickname': 'wyoung', 'address': {'street': '22636 Bruce Falls', 'city': 'Lake Jay', 'state': 'Alabama', 'zip': '46103'}, 'genres': ['Electronic', 'Soul', 'Jazz', 'Punk', 'Techno', 'R&B', 'Disco'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Victoria', 'last_name': 'Burke'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_7DoaAFIERm-C', 'email': 'milesjoshua@protonmail.com', 'joined_date': '2022-12-10', 'nickname': 'milesjoshua', 'address': {'street': '2402 Anderson Glens Apt. 163', 'city': 'Simonshire', 'state': 'Montana', 'zip': '30240'}, 'genres': ['Disco', 'Metal', 'Rock', 'Techno', 'Soul', 'Jazz', 'Blues', 'Hip-Hop'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Rebekah', 'last_name': 'Wilkerson'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Mw3ICnqUTdW7', 'email': 'roger54@icloud.com', 'joined_date': '2016-04-24', 'nickname': 'roger54', 'address': {'street': '5326 Jessica Land Suite 702', 'city': 'Waynehaven', 'state': 'Montana', 'zip': '11842'}, 'genres': ['Disco', 'Blues', 'Folk', 'Electronic', 'Indie', 'Classical'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Corey', 'last_name': 'Wang'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_9X5q1MJPSYKf', 'email': 'nataliecoffey@mail.com', 'joined_date': '2021-03-27', 'nickname': 'nataliecoffey', 'address': {'street': '271 Thomas Vista Apt. 021', 'city': 'North Maryville', 'zip': '79004'}, 'genres': ['Techno', 'Soul'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Linda', 'last_name': 'Walsh'}, 'stage_name': 'randy08', 'bio': 'Note general culture chair have state almost. Film head speak become allow billion.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_TSNyT_eKRD6H', 'email': 'dicksonelizabeth@yahoo.com', 'joined_date': '2020-05-30', 'nickname': 'dicksonelizabeth', 'address': {'street': '77923 Tara Hills Suite 334', 'city': 'Port Thomasborough', 'state': 'Pennsylvania', 'zip': '10785'}, 'genres': ['R&B', 'Rock', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Lisa', 'last_name': 'Moore'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Hv4LvIh-Tb-7', 'email': 'danielharrison@icloud.com', 'joined_date': '2017-08-12', 'nickname': 'danielharrison', 'address': {'street': '76264 Jo Summit', 'city': 'North Stephanie', 'state': 'West Virginia', 'zip': '23703'}, 'genres': ['Soul', 'Metal', 'Classical', 'Funk', 'R&B', 'Gospel', 'Reggae'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Tammy', 'last_name': 'Villarreal'}, 'bio': 'Assume though American which or. Behavior blue provide certainly call last industry. Enter beat base any.\nRace popular little certain. Arrive name face throw speech.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_UByyhtAaQx6C', 'email': 'jennifer27@foxmail.com', 'joined_date': '2021-09-02', 'nickname': 'jennifer27', 'address': {'street': '6197 Nicole Shores', 'state': 'Oklahoma', 'zip': '85474'}, 'genres': ['Soul', 'Funk', 'Disco'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Jordan', 'last_name': 'Ward'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_yL4vaenSTauS', 'email': 'fowlerjason@college.edu', 'joined_date': '2022-06-17', 'nickname': 'fowlerjason', 'address': {'street': '5596 Holt Crossing', 'city': 'North Michael', 'state': 'Pennsylvania', 'zip': '89025'}, 'genres': ['Jazz'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Heather', 'last_name': 'Smith'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_vtqyO4SoSdis', 'email': 'amandawatkins@mail.com', 'joined_date': '2018-08-20', 'nickname': 'amandawatkins', 'address': {'street': '9818 Martinez Groves', 'city': 'Lake Gary', 'state': 'New Jersey', 'zip': '71133'}, 'genres': ['Soul', 'Indie', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Linda', 'last_name': 'Rivera'}, 'stage_name': 'malonecarla', 'bio': 'Important perform probably. Thousand authority develop for.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_nIj-10G4QKqO', 'email': 'turnerkayla@icloud.com', 'joined_date': '2019-08-10', 'nickname': 'turnerkayla', 'address': {'street': '19285 Martinez Drives', 'city': 'North Toddmouth', 'state': 'Iowa', 'zip': '02182'}, 'genres': ['Gospel', 'Electronic', 'R&B', 'Latin', 'Folk', 'Soul'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Edwin', 'last_name': 'Patterson'}, 'stage_name': 'lisajones', 'bio': 'Worry really southern assume fund plan or.\nWhite station like go.\nCentury bit wait state. Reality economy real man box Democrat drop. Allow be either someone huge. End wait ask.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_6tB_BjZQR3O8', 'email': 'webersara@hotmail.com', 'joined_date': '2019-01-03', 'nickname': 'webersara', 'address': {'street': '8958 Johnson Park', 'city': 'North Martin', 'state': 'New Jersey'}, 'genres': ['Techno', 'Funk', 'Rock', 'Disco', 'Electronic', 'Country', 'Soul'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Michael', 'last_name': 'Hunter'}, 'stage_name': 'ooconnor', 'bio': 'Two above difficult administration. Site wonder natural religious especially let. Lose sit color none treat wide. War new lay strong outside above that.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_DC10fr12Tkal', 'email': 'fwilson@outlook.com', 'joined_date': '2021-03-01', 'nickname': 'fwilson', 'address': {'street': '3026 Holden View Suite 495', 'city': 'South Jacksonport', 'state': 'Montana', 'zip': '01774'}, 'genres': ['Electronic', 'Latin', 'Indie', 'Gospel', 'Folk', 'Classical'], 'is_listener': False, 'is_artist': True, 'bio': 'Reveal teacher baby event we collection matter ten. Show society pretty responsibility. Present artist plant such five fast.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_gKktSJtcTWCh', 'email': 'perrytyler@yahoo.com', 'joined_date': '2017-07-05', 'nickname': 'perrytyler', 'address': {'street': '99949 Mendez Dam', 'city': 'North Fredton', 'state': 'Nebraska', 'zip': '17429'}, 'genres': ['Country', 'Soul', 'Pop', 'Rock'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Doris', 'last_name': 'Baker'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_KCiHPHzfRd2z', 'email': 'xbaker@hotmail.com', 'joined_date': '2015-11-05', 'nickname': 'xbaker', 'address': {'city': 'Candiceburgh', 'state': 'Arkansas'}, 'genres': ['Rock', 'Pop', 'Latin', 'Blues'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Kelsey', 'last_name': 'Everett'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_sqDTOFSoTaKf', 'email': 'ellengibson@yahoo.com', 'joined_date': '2018-02-08', 'nickname': 'ellengibson', 'address': {'street': '9400 Wu Court', 'city': 'New Andre', 'state': 'New Hampshire', 'zip': '95877'}, 'genres': ['Indie', 'Punk', 'Soul'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Nicole', 'last_name': 'Mcgee'}, 'stage_name': 'melissa51', 'bio': 'Establish class increase author. Change ever rule would light career to. Attack federal share treat car once idea fight.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_kHWE86TpSfGv', 'email': 'nataliedean@gmail.com', 'joined_date': '2018-07-26', 'nickname': 'nataliedean', 'address': {'street': '7314 Williams Unions Apt. 397', 'state': 'Montana', 'zip': '07136'}, 'genres': ['Indie', 'Funk', 'Pop', 'Techno', 'Latin', 'Gospel'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Charles', 'last_name': 'Yu'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_VtePmW1wRa-D', 'email': 'david90@college.edu', 'joined_date': '2018-01-06', 'nickname': 'david90', 'address': {'street': '53964 Mary Cape Apt. 375', 'city': 'South Virginiafort', 'state': 'North Carolina', 'zip': '18784'}, 'genres': ['Punk', 'Latin', 'Soul', 'Reggae', 'Electronic'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Louis', 'last_name': 'Taylor'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Ab5RqLMJT8yV', 'email': 'sarah38@protonmail.com', 'joined_date': '2020-09-01', 'nickname': 'sarah38', 'address': {'city': 'New Christopher', 'state': 'North Carolina', 'zip': '32099'}, 'genres': ['Gospel', 'Techno', 'Funk', 'Folk', 'R&B'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Lynn', 'last_name': 'Morgan'}, 'stage_name': 'daviddeborah', 'bio': 'Prove source minute player sing. Need set individual its pull political catch. High carry tend majority.\nFire enjoy sell. During play increase free black speech.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_WEvfrZirTdKc', 'email': 'matthewgregory@mail.com', 'joined_date': '2021-12-06', 'nickname': 'matthewgregory', 'address': {'street': '47589 Reed Shoals Suite 727', 'city': 'Port Shelby'}, 'genres': ['Classical', 'Rock', 'Disco', 'Country', 'Folk', 'Gospel'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Samantha', 'last_name': 'West'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_NziZgakgSKuz', 'email': 'sjohnston@yahoo.com', 'joined_date': '2020-11-10', 'nickname': 'sjohnston', 'address': {'street': '380 Hamilton Mill Apt. 632', 'city': 'Donaldmouth', 'state': 'Ohio', 'zip': '51013'}, 'genres': ['Hip-Hop', 'R&B', 'Disco', 'Rock'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Jeremy', 'last_name': 'Clay'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_sZikBL6IRuqn', 'email': 'rebeccamoore@protonmail.com', 'joined_date': '2019-08-20', 'nickname': 'rebeccamoore', 'address': {'street': '025 Andrea Isle', 'city': 'North Danielborough', 'state': 'Illinois', 'zip': '03747'}, 'genres': ['Punk', 'Hip-Hop', 'Classical', 'Folk'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Edgar', 'last_name': 'Mckenzie'}, 'bio': 'Size theory program various. Would glass shoulder realize. Only easy relate name free.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_pCOh7KAiQAuf', 'email': 'michelle32@outlook.com', 'joined_date': '2018-04-29', 'nickname': 'michelle32', 'address': {'street': '503 Grace Alley', 'city': 'Hendricksfurt', 'state': 'Vermont', 'zip': '29886'}, 'genres': ['Pop', 'Reggae', 'Techno', 'Country', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Elizabeth', 'last_name': 'Myers'}, 'bio': 'Fish particular public baby. Very despite ten. Scientist specific election page.\nMethod right live its opportunity exactly able.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_0NK9A5EwTE2b', 'email': 'john15@foxmail.com', 'joined_date': '2017-07-05', 'nickname': 'john15', 'address': {'street': '372 Kristen Rapid', 'city': 'Port Kristiefort', 'state': 'Massachusetts', 'zip': '20326'}, 'genres': ['Techno'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Phillip', 'last_name': 'Myers'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_SItDAu-HTmCE', 'email': 'kimberlymarshall@college.edu', 'joined_date': '2016-01-26', 'nickname': 'kimberlymarshall', 'address': {'city': 'New Stephanie', 'state': 'Massachusetts'}, 'genres': ['Reggae', 'Rock', 'Metal', 'R&B'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Rachel', 'last_name': 'Schmidt'}, 'stage_name': 'patrick62', 'bio': 'People least interview away employee large. Age experience window nearly be.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_oQthpKRiShiY', 'email': 'charleslewis@university.edu', 'joined_date': '2017-10-15', 'nickname': 'charleslewis', 'address': {'street': '8686 Cervantes Locks', 'city': 'Marshallfurt', 'state': 'Hawaii', 'zip': '58621'}, 'genres': ['Country', 'Classical', 'Soul', 'Indie', 'Metal', 'Techno', 'Blues', 'Pop', 'Gospel', 'Funk'], 'is_listener': False, 'is_artist': True, 'stage_name': 'dorseyelizabeth', 'bio': 'Among very maybe onto. Two table fact exactly wait health.\nReveal player begin choose participant story himself. One Mrs war newspaper.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_Uswx1EG7QeK3', 'email': 'seanthompson@protonmail.com', 'joined_date': '2017-01-20', 'nickname': 'seanthompson', 'address': {'street': '51746 Lopez Ports', 'city': 'Samanthaburgh', 'state': 'Montana', 'zip': '47086'}, 'genres': ['Techno', 'Country', 'Pop', 'Disco'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Jade', 'last_name': 'Clarke'}, 'stage_name': 'tkelly', 'bio': 'Stop result common but understand. Central later million need.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_UiCOZjARTfKs', 'email': 'douglasbennett@yahoo.com', 'joined_date': '2021-02-15', 'nickname': 'douglasbennett', 'address': {'street': '451 Sherri Springs Suite 211', 'city': 'South John', 'state': 'Utah', 'zip': '37144'}, 'genres': ['Blues', 'Disco', 'Folk', 'Hip-Hop', 'Techno', 'Gospel', 'Reggae'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Deanna', 'last_name': 'Boyd'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_oEKaMQCoSRKd', 'email': 'bartlettmary@protonmail.com', 'joined_date': '2020-06-23', 'nickname': 'bartlettmary', 'address': {'street': '6392 Thomas Divide Suite 317', 'city': 'Peterfort', 'state': 'New York'}, 'genres': ['Funk', 'Rock', 'Techno', 'Pop', 'Hip-Hop'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Brittany', 'last_name': 'Martinez'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_TnnXXwkUQU29', 'email': 'tina44@yahoo.com', 'joined_date': '2020-08-18', 'nickname': 'tina44', 'address': {'city': 'South Emma', 'zip': '29106'}, 'genres': ['Metal', 'Indie', 'Funk', 'Folk', 'Blues', 'Punk'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Kathryn', 'last_name': 'Santos'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_RDsTWWXwTB-l', 'email': 'jeanettehoffman@foxmail.com', 'joined_date': '2017-09-04', 'nickname': 'jeanettehoffman', 'address': {'city': 'Jameston', 'state': 'Texas', 'zip': '71575'}, 'genres': ['R&B', 'Jazz', 'Punk', 'Gospel', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Hannah', 'last_name': 'Schmidt'}, 'stage_name': 'orrtamara', 'bio': 'I sister choose great now. Benefit picture speech take. Poor upon how your.\nEnjoy order us tree identify value writer. Want structure those sister statement artist gun. Because item none his.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_k6vGR1aMSpeD', 'email': 'smithhelen@protonmail.com', 'joined_date': '2022-11-06', 'nickname': 'smithhelen', 'address': {'street': '7038 Sellers Gardens Apt. 132', 'city': 'Timothyberg', 'state': 'Louisiana', 'zip': '21224'}, 'genres': ['Rock', 'Latin', 'R&B', 'Pop', 'Jazz', 'Reggae'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Nathan', 'last_name': 'Torres'}, 'bio': 'Size why develop have relate chair since. Both chair night character. Play movement against.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_wQD7tpOzS564', 'email': 'ruthwilliams@outlook.com', 'joined_date': '2017-06-10', 'nickname': 'ruthwilliams', 'address': {'city': 'Kingburgh', 'state': 'North Dakota', 'zip': '63468'}, 'genres': ['Techno', 'Funk', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Ashlee', 'last_name': 'Freeman'}, 'stage_name': 'paul76', 'bio': 'Difficult member performance thing. Yet range just focus. Minute know course knowledge attention network. Those knowledge occur have her.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_2lW90BgUT6C1', 'email': 'marcocox@hotmail.com', 'joined_date': '2022-05-07', 'nickname': 'marcocox', 'address': {'street': '6033 Graham Drive Suite 333', 'city': 'Goodfort', 'zip': '64692'}, 'genres': ['Jazz', 'Classical', 'Rock', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Grant', 'last_name': 'Clark'}, 'stage_name': 'jenkinsdaniel', 'bio': 'Democratic activity late standard.\nMeasure buy health eat watch life. Environmental he recognize event government clear.\nDirection yeah space type edge. Together national however this interview.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_vv3Wv_QNThW0', 'email': 'rporter@protonmail.com', 'joined_date': '2022-06-27', 'nickname': 'rporter', 'address': {'street': '56469 Mendez Drive', 'city': 'Millerside', 'state': 'New Mexico', 'zip': '26945'}, 'genres': ['Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Sandra', 'last_name': 'Campbell'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_Bce068lNSWel', 'email': 'baileymary@protonmail.com', 'joined_date': '2017-06-29', 'nickname': 'baileymary', 'address': {'street': '126 French Trail Suite 480', 'city': 'South Sherri', 'zip': '04627'}, 'genres': ['Blues'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Joseph', 'last_name': 'Davis'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_t747q7lLT52_', 'email': 'samanthawilliams@foxmail.com', 'joined_date': '2022-10-11', 'nickname': 'samanthawilliams', 'address': {'street': '17116 Renee Creek', 'city': 'South Henryberg', 'state': 'Montana'}, 'genres': ['Country', 'Indie', 'Funk', 'Folk'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Madison', 'last_name': 'Cooper'}, 'stage_name': 'fgrimes', 'bio': 'Task question hit should. National next above draw determine morning hit hand. Everybody hard me section star.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_H1fKJ_-QTl2K', 'email': 'ewilliams@mail.com', 'joined_date': '2016-07-23', 'nickname': 'ewilliams', 'address': {'street': '0764 Yu Ways Apt. 973', 'state': 'Maine', 'zip': '55498'}, 'genres': ['Country', 'Techno', 'Classical', 'Reggae', 'Jazz', 'Metal', 'Disco', 'Rock', 'R&B', 'Latin'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Mark', 'last_name': 'Allen'}, 'stage_name': 'simmonssarah', 'bio': 'Nature heart apply wall want. Rather student official nature fast street her show. Seem green listen after wall.\nKey evidence hot hard. They ground or people bag ready food. Catch month trip kind.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_l5LPFQuuSE61', 'email': 'rlowe@outlook.com', 'joined_date': '2021-06-26', 'nickname': 'rlowe', 'address': {'city': 'North Molly', 'state': 'Nebraska', 'zip': '56091'}, 'genres': ['Indie', 'Techno'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Brandon', 'last_name': 'Hale'}, 'bio': 'Walk citizen window year security interest. At position save perhaps.\nDecide tough spring popular somebody. Drug city pull low. Deep source quickly sea agent especially reflect.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_gI546KaGThGm', 'email': 'wmoreno@college.edu', 'joined_date': '2022-05-27', 'nickname': 'wmoreno', 'address': {'street': '8490 Arnold Tunnel', 'city': 'Julieport', 'state': 'Indiana', 'zip': '14395'}, 'genres': ['Techno', 'Disco', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Randall', 'last_name': 'Sanders'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_W01PpD79Qta6', 'email': 'gina75@outlook.com', 'joined_date': '2016-01-23', 'nickname': 'gina75', 'address': {'city': 'Breannamouth', 'state': 'Michigan', 'zip': '72695'}, 'genres': ['Electronic', 'Folk', 'Rock', 'R&B', 'Latin'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Michael', 'last_name': 'Smith'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_xgvgpV-XS3qB', 'email': 'pchan@college.edu', 'joined_date': '2018-06-27', 'nickname': 'pchan', 'address': {'state': 'Wyoming'}, 'genres': ['Country', 'Gospel', 'Punk', 'Reggae'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Paul', 'last_name': 'Anderson'}, 'stage_name': 'michael77', 'bio': 'About through fill anyone address. Hair customer TV should.\nTree film message opportunity follow include. Box line heart nearly lose respond. Professional ask fight force history.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_Qh6pvMtdTJ-T', 'email': 'mcguiresheila@outlook.com', 'joined_date': '2018-05-13', 'nickname': 'mcguiresheila', 'address': {'street': '5813 Miller Groves', 'city': 'North David', 'state': 'New York', 'zip': '86827'}, 'genres': ['Reggae', 'Folk', 'Indie', 'Soul', 'Latin'], 'is_listener': False, 'is_artist': True, 'bio': 'Art beat value agency kid this. Order year later bad write would up.\nGeneral action understand north. Majority through especially. Support it carry here speak interest.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_FiLqt18hQC-2', 'email': 'thompsoneric@gmail.com', 'joined_date': '2015-04-02', 'nickname': 'thompsoneric', 'address': {'street': '6184 Eric Court', 'state': 'Nebraska', 'zip': '43117'}, 'genres': ['Indie', 'Punk', 'Funk', 'Pop'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Kristen', 'last_name': 'Smith'}, 'bio': 'Part property activity say likely could so. Interview now yet impact charge understand everything each. After if lot worry concern there.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_VCE6bxjKSpC_', 'email': 'velasquezmargaret@university.edu', 'joined_date': '2017-05-01', 'nickname': 'velasquezmargaret', 'address': {'street': '058 Kimberly Stream', 'state': 'South Dakota', 'zip': '38731'}, 'genres': ['Techno', 'Jazz', 'Gospel', 'Latin', 'Classical', 'Rock', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Cameron', 'last_name': 'Hill'}, 'stage_name': 'patriciagreen', 'bio': 'Enough important avoid everybody. Work call place side a letter sit. You compare perhaps view hope administration. Prove nature deep material deal shake.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_v7faevcPRta8', 'email': 'anthony59@college.edu', 'joined_date': '2021-01-28', 'nickname': 'anthony59', 'address': {'city': 'North Georgemouth', 'state': 'Iowa', 'zip': '32389'}, 'genres': ['Funk', 'Jazz'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Brandy', 'last_name': 'Richardson'}, 'bio': 'Sit could final us police affect third. Admit pretty civil treat against.\nModel simply allow what father. Election no general million. Team tend career skill be.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_jkHSEf8bSvKS', 'email': 'nicole39@yahoo.com', 'joined_date': '2019-03-17', 'nickname': 'nicole39', 'address': {'street': '30993 Derrick Fork Suite 034', 'city': 'West Kevin', 'state': 'New Hampshire'}, 'genres': ['Latin', 'Metal', 'Country', 'Blues', 'Funk'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Dana', 'last_name': 'Foley'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_KA9f7xi1S7Or', 'email': 'johnsontanya@yahoo.com', 'joined_date': '2017-10-13', 'nickname': 'johnsontanya', 'address': {'city': 'East Rita', 'zip': '93844'}, 'genres': ['Jazz', 'Electronic', 'Pop', 'Techno', 'Indie', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'James', 'last_name': 'Davenport'}, 'bio': 'Measure hair painting whose. Small consider challenge mind plan community leader event.\nEnd adult believe often. Matter would call forget. What student discover eat hear lose.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_J0nH1iPARimD', 'email': 'ucastaneda@yahoo.com', 'joined_date': '2020-01-20', 'nickname': 'ucastaneda', 'address': {'street': '0694 Charles Canyon', 'city': 'South James', 'state': 'Arizona', 'zip': '01514'}, 'genres': ['Pop', 'Indie', 'Gospel', 'R&B', 'Folk'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Edwin', 'last_name': 'Green'}}, Type: <class 'dict'>
# ...
# Data: {'user_id': 'user_KsQxIuc5RBez', 'email': 'paynedavid@university.edu', 'joined_date': '2018-07-15', 'nickname': 'paynedavid', 'address': {'street': '3446 Cynthia Unions Apt. 809', 'city': 'Christietown', 'state': 'Colorado'}, 'genres': ['Reggae'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Stephen', 'last_name': 'Graham'}, 'stage_name': 'cynthia14', 'bio': 'Determine focus impact image instead try and. Chair pass start truth head.\nAll factor you join live. Eat outside news live.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_IDSiOadnQNGL', 'email': 'aaron76@icloud.com', 'joined_date': '2016-03-28', 'nickname': 'aaron76', 'address': {'street': '61545 Phillips Mountains', 'city': 'Phillipsberg', 'state': 'Rhode Island', 'zip': '27312'}, 'genres': ['Country', 'Folk', 'Techno', 'Funk', 'Punk'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Timothy', 'last_name': 'Morris'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_uU2RbAQQShyX', 'email': 'callen@icloud.com', 'joined_date': '2016-01-23', 'nickname': 'callen', 'address': {'street': '864 Brian Ranch Apt. 164', 'city': 'Debrachester'}, 'genres': ['R&B', 'Funk', 'Hip-Hop', 'Blues', 'Electronic', 'Reggae'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Justin', 'last_name': 'Krause'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_g7MCkYsfS7yC', 'email': 'maymark@icloud.com', 'joined_date': '2019-02-26', 'nickname': 'maymark', 'address': {'street': '131 Johnson Prairie', 'city': 'Hannaborough', 'state': 'Washington', 'zip': '76136'}, 'genres': ['Gospel', 'Pop', 'Disco', 'Rock', 'Electronic', 'Funk', 'Soul', 'Folk'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Jennifer', 'last_name': 'White'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_xxn4pa7qSGGR', 'email': 'bradshawshaun@hotmail.com', 'joined_date': '2017-05-10', 'nickname': 'bradshawshaun', 'address': {'street': '610 Smith Trail', 'city': 'New Carmenport', 'state': 'Florida', 'zip': '32782'}, 'genres': ['Folk', 'Indie', 'Blues', 'Electronic', 'Punk'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Joann', 'last_name': 'Wallace'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_iqcAJek3Sqqn', 'email': 'duranjoshua@hotmail.com', 'joined_date': '2022-12-12', 'nickname': 'duranjoshua', 'address': {'street': '03158 Evans Via Suite 281', 'city': 'Ramseyside', 'state': 'Virginia'}, 'genres': ['Latin', 'Hip-Hop', 'Country', 'Gospel'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Susan', 'last_name': 'Booth'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_7RN0kRAhS5KD', 'email': 'marisa58@mail.com', 'joined_date': '2018-10-04', 'nickname': 'marisa58', 'address': {'street': '4334 Lopez Row Apt. 757', 'city': 'Kimborough'}, 'genres': ['Folk', 'R&B', 'Pop', 'Country', 'Latin'], 'is_listener': True, 'is_artist': False, 'subscription': 'free', 'real_name': {'first_name': 'Anthony', 'last_name': 'Flowers'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_tROZfrRhQ66m', 'email': 'ncollins@hotmail.com', 'joined_date': '2018-01-05', 'nickname': 'ncollins', 'address': {'street': '660 Eric Parkway', 'city': 'North Keith'}, 'genres': ['R&B', 'Punk', 'Pop', 'Classical'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Brittany', 'last_name': 'Moreno'}, 'stage_name': 'jamesmays', 'bio': 'Assume later head line important. Night authority spring role maybe commercial west draw. Deal trial wall lot mention.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_PeMszq7gTF-G', 'email': 'dustin63@gmail.com', 'joined_date': '2016-01-14', 'nickname': 'dustin63', 'address': {'street': '52229 Matthew Canyon Apt. 794', 'city': 'East Sarahmouth', 'state': 'North Carolina', 'zip': '65021'}, 'genres': ['Rock', 'Blues', 'Disco'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Seth', 'last_name': 'Dodson'}, 'bio': 'Service often control think available spend political wife. Too could carry send still.\nLand also explain run. Sell over act personal.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_QzRS-u58Q2ua', 'email': 'ericmccall@college.edu', 'joined_date': '2021-10-05', 'nickname': 'ericmccall', 'address': {'street': '80680 Rodriguez Hill Suite 937', 'city': 'Lake Kevinmouth', 'state': 'Arkansas', 'zip': '46259'}, 'genres': ['Gospel', 'Indie', 'Country', 'Jazz', 'Soul'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Terri', 'last_name': 'Pham'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_2EVs8o0mSj6i', 'email': 'brittany95@yahoo.com', 'joined_date': '2018-08-23', 'nickname': 'brittany95', 'address': {'street': '314 Craig Locks Suite 547', 'city': 'Joshuashire', 'state': 'Montana', 'zip': '16120'}, 'genres': ['Indie', 'Electronic', 'Pop', 'Punk', 'Latin', 'Folk'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Jason', 'last_name': 'Davis'}, 'stage_name': 'rreynolds', 'bio': 'Land operation guess his commercial organization always. Customer agree until movie six.\nSit significant central travel. Member growth the.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_UYNWUATKSaac', 'email': 'kimberlymartin@gmail.com', 'joined_date': '2017-05-12', 'nickname': 'kimberlymartin', 'address': {'street': '00835 Baird Circles', 'city': 'Malikport', 'zip': '93752'}, 'genres': ['Latin'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Beth', 'last_name': 'Copeland'}, 'stage_name': 'showard', 'bio': 'Mention capital measure agreement over break pass trip. Product production water fine stock generation. Build pattern natural.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_kyFAzmXuTWGe', 'email': 'scottnorman@protonmail.com', 'joined_date': '2017-02-16', 'nickname': 'scottnorman', 'address': {'street': '4729 Crawford Brooks', 'city': 'Stewartview', 'state': 'Delaware', 'zip': '21491'}, 'genres': ['Country', 'Latin', 'Blues', 'Electronic', 'Metal'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Brian', 'last_name': 'Morrison'}, 'stage_name': 'mary41', 'bio': 'Until describe these room he foot. Action woman according as. Inside until peace yes PM drop commercial.\nThose southern total Mr sign out create. Mention point recent within group sister long.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_ejUE3fFPRDCx', 'email': 'rjones@mail.com', 'joined_date': '2017-10-06', 'nickname': 'rjones', 'address': {'city': 'South Daniel', 'state': 'Arkansas', 'zip': '98301'}, 'genres': ['R&B', 'Folk', 'Disco', 'Soul', 'Classical'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Michelle', 'last_name': 'Drake'}, 'stage_name': 'bauernicole', 'bio': 'Approach course left order reflect commercial bit. Forget choice nature character remain.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_2VVLRsKtTV6A', 'email': 'robertsonbrandon@hotmail.com', 'joined_date': '2020-06-11', 'nickname': 'robertsonbrandon', 'address': {'street': '7287 April Turnpike', 'city': 'Markport', 'state': 'Vermont'}, 'genres': ['Folk', 'Gospel', 'Punk', 'Pop'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'David', 'last_name': 'Ramirez'}, 'stage_name': 'douglas43', 'bio': 'Arm shake him what other yard people. Firm leader each medical action goal training. Until suddenly visit myself his because.\nQuite specific table we PM realize. Kind final coach.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_cN7i5wcHQJSY', 'email': 'mary25@hotmail.com', 'joined_date': '2018-01-02', 'nickname': 'mary25', 'address': {'city': 'Lake Donald', 'state': 'Wisconsin', 'zip': '45368'}, 'genres': ['Pop', 'Techno', 'Soul'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Amanda', 'last_name': 'Miller'}, 'stage_name': 'ujohnson', 'bio': 'Seven challenge generation technology base analysis matter. Too travel mention team. Laugh scene difficult painting.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_jMcvue4GQwWM', 'email': 'monica21@foxmail.com', 'joined_date': '2021-11-12', 'nickname': 'monica21', 'address': {'street': '80379 Philip Corners', 'city': 'Lake Tarafurt', 'state': 'California', 'zip': '78772'}, 'genres': ['Indie', 'Metal'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Cheryl', 'last_name': 'Quinn'}, 'stage_name': 'michaelabbott', 'bio': 'Pay game note deal. Expect why tell sometimes read.\nSeveral at from future. Smile course people available. Usually throw wish attack themselves whole education.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_dRzbjrfITMOq', 'email': 'pattonthomas@university.edu', 'joined_date': '2015-10-09', 'nickname': 'pattonthomas', 'address': {'street': '841 Benjamin Loop', 'zip': '98193'}, 'genres': ['Folk', 'Metal', 'Blues', 'Electronic'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Zoe', 'last_name': 'Richards'}, 'stage_name': 'kcarter', 'bio': 'Oil identify see above edge. Kid his what forward. Question early election money current.\nPrepare position condition husband. White wear care.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_uosl_pi6R_6-', 'email': 'robbinsjennifer@hotmail.com', 'joined_date': '2017-12-25', 'nickname': 'robbinsjennifer', 'address': {'street': '37176 Hodges Village', 'city': 'New Danielle', 'state': 'New Mexico', 'zip': '80310'}, 'genres': ['Metal', 'Latin'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Dana', 'last_name': 'Myers'}, 'stage_name': 'maxrodgers', 'bio': 'House store current employee put manage number bill. Deal throw help claim off outside summer. Safe natural executive responsibility your no show. Local international culture hotel.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_ZGw-0qM6TRG7', 'email': 'jessica00@mail.com', 'joined_date': '2019-03-25', 'nickname': 'jessica00', 'address': {'street': '5038 Lori Estate Suite 079', 'city': 'South Martinside', 'state': 'Rhode Island', 'zip': '08086'}, 'genres': ['Gospel', 'Punk', 'Metal', 'Classical', 'Blues', 'Soul'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Stacy', 'last_name': 'Williams'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_H9bgq2YqRaqU', 'email': 'calderontodd@university.edu', 'joined_date': '2019-06-25', 'nickname': 'calderontodd', 'address': {'street': '158 Lopez Street Apt. 610', 'city': 'Rochafurt', 'state': 'Ohio', 'zip': '38905'}, 'genres': ['Techno'], 'is_listener': False, 'is_artist': True, 'stage_name': 'eluna', 'bio': 'Side nearly again finish team. Agency billion water charge. Among authority purpose course.\nThese moment claim floor cup stock.\nSecond black out window enjoy. System any sister west town turn.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_-Dka8ctZSUmF', 'email': 'peterszachary@outlook.com', 'joined_date': '2015-08-25', 'nickname': 'peterszachary', 'address': {'city': 'Lake Kevin', 'state': 'California'}, 'genres': ['Folk', 'R&B', 'Metal', 'Latin', 'Funk', 'Jazz'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Barbara', 'last_name': 'Peterson'}, 'stage_name': 'nnelson', 'bio': 'Summer per seven dinner structure. Those activity crime billion draw manage.\nIncrease they so analysis meeting tell. Full industry side store agree.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_YKYTVUctR9iJ', 'email': 'melissa63@university.edu', 'joined_date': '2019-05-02', 'nickname': 'melissa63', 'address': {'street': '593 Ryan Roads', 'city': 'Amberberg', 'zip': '85021'}, 'genres': ['Funk', 'Blues', 'Soul', 'Electronic', 'Hip-Hop'], 'is_listener': True, 'is_artist': True, 'subscription': 'yearly', 'real_name': {'first_name': 'Richard', 'last_name': 'Sanders'}, 'stage_name': 'oconnellkendra', 'bio': 'Prevent day property. No statement position worry risk. City goal anything friend room still forget fly.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_h2E8HKh2QNaM', 'email': 'roy72@protonmail.com', 'joined_date': '2020-01-23', 'nickname': 'roy72', 'address': {'street': '78773 Erin Keys', 'city': 'Josephmouth', 'zip': '95229'}, 'genres': ['Indie', 'Pop'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Alyssa', 'last_name': 'Garcia'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_LIQaIlkRQB6u', 'email': 'solisjessica@university.edu', 'joined_date': '2015-05-26', 'nickname': 'solisjessica', 'address': {'city': 'West Sara', 'state': 'Colorado', 'zip': '56922'}, 'genres': ['Gospel', 'R&B', 'Disco'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Linda', 'last_name': 'Warner'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_09cfO_MVSHOy', 'email': 'christopher89@mail.com', 'joined_date': '2021-08-07', 'nickname': 'christopher89', 'address': {'street': '1725 Warren Light', 'city': 'Port Bethanyfurt', 'state': 'Delaware', 'zip': '62154'}, 'genres': ['Soul', 'Techno', 'Disco', 'Funk', 'Pop', 'Reggae', 'Country'], 'is_listener': True, 'is_artist': False, 'subscription': 'monthly', 'real_name': {'first_name': 'Daniel', 'last_name': 'Woodard'}}, Type: <class 'dict'>
# Data: {'user_id': 'user_LN7vF4IZTI2Y', 'email': 'dianagarcia@college.edu', 'joined_date': '2020-04-16', 'nickname': 'dianagarcia', 'address': {'street': '37406 Mitchell Park', 'city': 'Michaelberg', 'state': 'Utah'}, 'genres': ['Punk', 'Gospel', 'Blues'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Stephanie', 'last_name': 'Pearson'}, 'stage_name': 'ycampbell', 'bio': 'Process certain explain guy service.\nNone standard major sport thing reflect particularly. View partner party sport happen. Decade stage large people choose performance.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_CDk8g2pJSaGj', 'email': 'calvinweaver@gmail.com', 'joined_date': '2019-06-18', 'nickname': 'calvinweaver', 'address': {'street': '36934 Wood Freeway Apt. 543', 'city': 'West Ashley', 'state': 'California', 'zip': '81526'}, 'genres': ['Pop', 'Hip-Hop', 'Classical', 'Country'], 'is_listener': True, 'is_artist': True, 'subscription': 'monthly', 'real_name': {'first_name': 'Christine', 'last_name': 'Nunez'}, 'stage_name': 'evelasquez', 'bio': 'Admit treatment fish wall thousand teacher. Offer bit quite fall where happen character.\nWater democratic east leader treatment single. Walk anyone tough while minute.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_NMvSx-dAR1C5', 'email': 'bettyhahn@hotmail.com', 'joined_date': '2015-08-29', 'nickname': 'bettyhahn', 'address': {'street': '177 Neil Divide Suite 025', 'city': 'East Heatherburgh', 'state': 'Washington', 'zip': '25073'}, 'genres': ['Techno', 'Jazz', 'Pop', 'R&B', 'Blues', 'Country'], 'is_listener': True, 'is_artist': True, 'subscription': 'free', 'real_name': {'first_name': 'Jason', 'last_name': 'Obrien'}, 'stage_name': 'wirwin', 'bio': 'Open stop level language.\nSignificant weight rather. State management inside commercial.\nVarious night different mention. Especially right help cell cause must few.'}, Type: <class 'dict'>
# Data: {'user_id': 'user_zzlOMP1fTtiz', 'email': 'katherineingram@hotmail.com', 'joined_date': '2022-04-03', 'nickname': 'katherineingram', 'address': {'street': '474 Harris Crossroad Suite 824', 'city': 'Lopezbury', 'state': 'Wisconsin', 'zip': '09808'}, 'genres': ['Disco', 'Reggae', 'Jazz', 'Techno', 'Metal'], 'is_listener': True, 'is_artist': False, 'subscription': 'yearly', 'real_name': {'first_name': 'Savannah', 'last_name': 'Watson'}}, Type: <class 'dict'>

# %%
# Q1.a
# From the outout of Q1.a, the type is Python dictionary.

# %%
# Q1.b
# Your Answer:

# The function `read_json_as_datastream` reads a file containing JSON objects (one per line) 
# into a PyFlink data stream using the provided file path and execution environment.
# 
# The class `JsonObjectMapFunction` is a custom implementation of the PyFlink `MapFunction` 
# interface. It processes each line of the file (received as a string) and converts it 
# into a Python dictionary using the `json.loads()` method. 
# This conversion is necessary because PyFlink reads data as plain text by default, 
# and the JSON strings need to be parsed into structured Python objects for downstream processing.
# 
# Example Workflow:
# 1. `env.read_text_file(file_path)` reads the file line-by-line as strings.
# 2. `JsonObjectMapFunction.map()` is applied to each line to parse it into a dictionary.
# 3. The resulting data stream consists of Python dictionaries, ready for further processing.

# %%
# Q1.c
# Your Answer: 

# The annotation (e.g., 3 > some data here) in the output indicates the parallel task ID (3) followed by 
# the processed data. The number identifies which parallel instance of the operator produced the output, 
# useful for debugging and understanding data distribution in Flink's distributed processing.

# %%
# Q2.a DataStream API
env = StreamExecutionEnvironment.get_execution_environment()
# Your code here
source = FileSource.for_record_stream_format(StreamFormat.text_line_format(), records_path).build()
data_stream = env.from_source(source, WatermarkStrategy.no_watermarks(), "records_source")

filtered_stream = data_stream \
    .map(lambda value: json.loads(value)) \
    .filter(lambda record: record["genre"] == "R&B" and record["is_album"] and len(record["songs"]) >= 12) \
    .map(lambda record: {
        "record_id": record["record_id"],
        "title": record["title"],
        "genre": record["genre"],
        "number_of_songs": len(record["songs"])
    })

filtered_stream.print()
env.execute("Q2.a DataStream API")
# Out:
# 3> {'record_id': 'record_KhNPrSUbSj--', 'title': 'Collection city service', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_Moz2GxQ1SvSk', 'title': 'Plant son lead', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_OR2mRtPRS-6B', 'title': 'Next', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_rjHeikQCTyqg', 'title': 'Office issue', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_Ic34zxUJS0ic', 'title': 'Education eye say', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_NaXmzSELRnii', 'title': 'Director way north', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_CaaF5m1MQbiF', 'title': 'Always home', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_ZHbWPiQWQTaB', 'title': 'Western city painting adult', 'genre': 'R&B', 'number_of_songs': 12}
# 3> {'record_id': 'record_T8luoEYGSgaI', 'title': 'Attention miss', 'genre': 'R&B', 'number_of_songs': 12}

# %%
# Q2.a Table API

# Your code here
t_env = TableEnvironment.create(EnvironmentSettings.in_streaming_mode())

t_env.execute_sql(f"""
    CREATE TABLE Records (
        record_id STRING,
        title STRING,
        genre STRING,
        is_album BOOLEAN,
        songs ARRAY<MAP<STRING, STRING>>
    ) WITH (
        'connector' = 'filesystem',
        'path' = '{records_path}',
        'format' = 'json'
    )
""")

result_table = t_env.sql_query("""
    SELECT
        record_id,
        title,
        genre,
        CARDINALITY(songs) AS number_of_songs
    FROM Records
    WHERE genre = 'R&B'
      AND is_album
      AND CARDINALITY(songs) >= 12
""")

result_table.execute().print()
# Out:
# +----+--------------------------------+--------------------------------+--------------------------------+-----------------+
# | op |                      record_id |                          title |                          genre | number_of_songs |
# +----+--------------------------------+--------------------------------+--------------------------------+-----------------+
# | +I |            record_KhNPrSUbSj-- |        Collection city service |                            R&B |              12 |
# | +I |            record_Moz2GxQ1SvSk |                 Plant son lead |                            R&B |              12 |
# | +I |            record_OR2mRtPRS-6B |                           Next |                            R&B |              12 |
# | +I |            record_rjHeikQCTyqg |                   Office issue |                            R&B |              12 |
# | +I |            record_Ic34zxUJS0ic |              Education eye say |                            R&B |              12 |
# | +I |            record_NaXmzSELRnii |             Director way north |                            R&B |              12 |
# | +I |            record_CaaF5m1MQbiF |                    Always home |                            R&B |              12 |
# | +I |            record_ZHbWPiQWQTaB |    Western city painting adult |                            R&B |              12 |
# | +I |            record_T8luoEYGSgaI |                 Attention miss |                            R&B |              12 |
# +----+--------------------------------+--------------------------------+--------------------------------+-----------------+
# 9 rows in set

# %%
# Q2.b DataStream API
env = StreamExecutionEnvironment.get_execution_environment()

# Your code here
filtered_stream = (
    env.from_source(
        FileSource.for_record_stream_format(StreamFormat.text_line_format(), review_likes_path).build(),
        WatermarkStrategy.no_watermarks(),
        "file_source"
    )
    .map(lambda line: json.loads(line))
    .filter(lambda x: x['user_id'] == "user_G91ZrXr4QOuT")
)

final_count = sum(1 for _ in filtered_stream.execute_and_collect())

print(f"Final like count for user 'user_G91ZrXr4QOuT': {final_count}")
# Out:
# Final like count for user 'user_G91ZrXr4QOuT': 536

# %%
# Q2.b Table API

# Your code here
env_settings = EnvironmentSettings.new_instance().in_batch_mode().build()
table_env = TableEnvironment.create(env_settings)


table_env.execute_sql(f"""
    CREATE TABLE ReviewLikes (
        user_id STRING,
        review_id STRING
    ) WITH (
        'connector' = 'filesystem',
        'path' = '{review_likes_path}',
        'format' = 'json'
    )
""")

result_table = table_env.sql_query("""
    SELECT COUNT(*) AS like_count
    FROM ReviewLikes
    WHERE user_id = 'user_G91ZrXr4QOuT'
""")

result_table.execute().print()
# Out:
# +----------------------+
# |           like_count |
# +----------------------+
# |                  536 |
# +----------------------+
# 1 row in set

# %%
# Q2.c DataStream API
env = StreamExecutionEnvironment.get_execution_environment()
env.set_runtime_mode(RuntimeExecutionMode.BATCH)
env.set_parallelism(1)

# Your code here
def calculate_session_duration(record):
    initiate_time = datetime.strptime(record["session_duration"]["initiate_at"], "%Y-%m-%d %H:%M:%S")
    leave_time = datetime.strptime(record["session_duration"]["leave_at"], "%Y-%m-%d %H:%M:%S")
    return {
        "user_id": record["user_id"],
        "session_duration_minutes": (leave_time - initiate_time).total_seconds() / 60
    }

class AggregateSessionDuration(ReduceFunction):
    def reduce(self, record1, record2):
        record1["session_duration_minutes"] += record2["session_duration_minutes"]
        return record1

result_stream = (
    env.read_text_file(sessions_path)
    .map(lambda line: calculate_session_duration(json.loads(line)))
    .filter(lambda record: record["user_id"] == "user_wQD7tpOzS564")
    .key_by(lambda record: record["user_id"])
    .reduce(AggregateSessionDuration())
)

result_stream.print()
env.execute("Q2.c DataStream API")
# Out:
# {'user_id': 'user_wQD7tpOzS564', 'session_duration_minutes': 1099.7499999999998}

# %%
# Q2.c Table API

# Your code here
env_settings = EnvironmentSettings.new_instance().in_batch_mode().build()
t_env = TableEnvironment.create(env_settings)

t_env.execute_sql(f"""
    CREATE TABLE sessions (
        user_id STRING,
        session_duration ROW<initiate_at STRING, leave_at STRING>
    ) WITH (
        'connector' = 'filesystem',
        'path' = '{sessions_path}',
        'format' = 'json'
    )
""")

result_table = t_env.sql_query("""
    SELECT 
        user_id, 
        SUM(
            UNIX_TIMESTAMP(session_duration.leave_at) - UNIX_TIMESTAMP(session_duration.initiate_at)
        ) / 60 AS total_session_duration_minutes
    FROM sessions
    WHERE user_id = 'user_wQD7tpOzS564'
    GROUP BY user_id
""")

result_table.execute().print()
# Out:
# +--------------------------------+--------------------------------+
# |                        user_id | total_session_duration_minutes |
# +--------------------------------+--------------------------------+
# |              user_wQD7tpOzS564 |                           1099 |
# +--------------------------------+--------------------------------+
# 1 row in set

# %%
# Q2.d
env = StreamExecutionEnvironment.get_execution_environment()

# Your code here
env = StreamExecutionEnvironment.get_execution_environment()
env.set_runtime_mode(RuntimeExecutionMode.BATCH)

def load_stream(file_path):
    return env.from_source(
        FileSource.for_record_stream_format(StreamFormat.text_line_format(), file_path).build(),
        WatermarkStrategy.no_watermarks(),
        "file_source"
    )

def parse_json(record):
    try:
        parsed_record = json.loads(record)
        if "song" in parsed_record and "record_id" in parsed_record["song"]:
            return {
                "record_id": parsed_record["song"]["record_id"],
                "replay_count": parsed_record.get("replay_count", 0),
            }
    except json.JSONDecodeError:
        pass
    return None

class ReplayAccumulator(KeyedProcessFunction):
    def open(self, runtime_context: RuntimeContext):
        self.total_replays = runtime_context.get_state(ValueStateDescriptor("total_replays", Types.LONG()))
        self.emitted = runtime_context.get_state(ValueStateDescriptor("emitted_flag", Types.BOOLEAN()))

    def process_element(self, value, ctx):
        current_total = (self.total_replays.value() or 0) + value["replay_count"]
        if not (self.emitted.value() or False) and current_total > 1000:
            self.emitted.update(True)
            yield value["record_id"]
        self.total_replays.update(current_total)

raw_stream = load_stream(sessions_path)
results_stream = (
    raw_stream
    .map(parse_json)
    .filter(lambda x: x is not None)
    .key_by(lambda record: record["record_id"])
    .process(ReplayAccumulator())
)

for record_id in results_stream.execute_and_collect():
    print(record_id)
# Out:
# record_eynz2XeqRvCC
# record_qIENcovfSFWX

# %%
# Q2.e
# Your code here
from pyflink.common.time import Time
from pyflink.datastream.functions import KeySelector, ProcessWindowFunction
from pyflink.datastream.window import TumblingEventTimeWindows


class SessionParser:
    @staticmethod
    def parse(json_line):
        record = json.loads(json_line)
        initiated_at = record.get('session_duration', {}).get('initiate_at', "1970-01-01 00:00:00")
        record['event_time'] = int(datetime.strptime(initiated_at, "%Y-%m-%d %H:%M:%S").timestamp())
        return record

class DateExtractor(KeySelector):
    def get_key(self, record):
        return datetime.utcfromtimestamp(record['event_time']).strftime('%Y-%m-%d')

class DailySessionCounter(ProcessWindowFunction):
    def process(self, key, context, elements):
        session_count = len(elements)
        if session_count >= 70:
            yield {"date": key, "session_count": session_count}

class TimestampAssigner:
    def extract_timestamp(self, record, record_timestamp):
        return record['event_time'] * 1000

def setup_environment():
    env = StreamExecutionEnvironment.get_execution_environment()
    env.set_runtime_mode(RuntimeExecutionMode.BATCH)
    return env

def build_dataflow():
    environment = setup_environment()
    raw_data = environment.read_text_file(sessions_path)
    parsed_data = raw_data.map(SessionParser.parse)
    watermark_strategy = WatermarkStrategy.for_monotonous_timestamps().with_timestamp_assigner(
        TimestampAssigner()
    )
    timestamped_data = parsed_data.assign_timestamps_and_watermarks(watermark_strategy)

    results = timestamped_data \
        .key_by(DateExtractor()) \
        .window(TumblingEventTimeWindows.of(Time.days(1))) \
        .process(DailySessionCounter())

    return results

def main():
    result_stream = build_dataflow()
    collected_results = list(result_stream.execute_and_collect())
    print("Session Count Analysis Results:")
    for result in collected_results:
        print(f"Date: {result['date']}, Session Count: {result['session_count']}")

if __name__ == "__main__":
    main()
# Out:
# Session Count Analysis Results:
# Date: 2023-03-03, Session Count: 74
# Date: 2023-06-12, Session Count: 71
# Date: 2023-11-11, Session Count: 78
# Date: 2023-11-13, Session Count: 72
# Date: 2024-03-15, Session Count: 73
# Date: 2024-06-28, Session Count: 72
# Date: 2024-08-12, Session Count: 71
# Date: 2024-10-08, Session Count: 70
